# %% [markdown]
# # Purpose
# To determine visual and auditory reaction times.
#
# # Procedure
# Followed the intructions to determine visual and auditory reactions by going to the websites provided. Websites were Human Benchmark and playback auditory. For vision, I followed the instructions by clicking the screen when green color came up and I would obtain ms of the time it tooked for me to react to the green color. This was repeated 10 times. For Auditory, I followed the instructions by pressing the space bar when I heard the sound and I would obtain ms of the time it took me to react to the sound. This was repeated 10 times.
#
# # Results

# %%
import matplotlib.pyplot as plt

# %%
VIS1_MEAN = 394.4
AUD1_MEAN = 505.8
VIS1_STD = 35.97
AUD1_STD = 117.37

# %%
# build a bar plot
plt.bar(['Person 1 Visual', 'Person 1 Auditory'],[VIS1_MEAN, AUD1_MEAN], yerr=[VIS1_STD, AUD1_STD], capsize=10)
plt.ylabel('Speed (msec)')
plt.xlabel("Reflex Type")
plt.title('Reflex Speed, Visual vs. Auditory')
# Out:
# Text(0.5, 1.0, 'Reflex Speed, Visual vs. Auditory')

# %% [markdown]
# # Discussion
# I think this test helped me understand how one can react to a change when its happening.
#
# # Conclusion
# I did observe a significant difference P value .01.
